# %% [markdown]
# # Working with RSS Feeds Lab
#
# Complete the following set of exercises to solidify your knowledge of parsing RSS feeds and extracting information from them.

# %% [markdown]
# * RSS stands for Rich Site Summary and uses standard web feed formats to publish frequently updated information: blog entries, news headlines, audio, video.

# %% [markdown]
# * __What is feedparser?__
#
# feedparser is a library that helps users to keep track over feeds such as RSS, and Atom in Python
# [source](https://github.com/kurtmckee/feedparser)
#
# - Documentation: https://pythonhosted.org/feedparser/

# %%
! pip install feedparser
# Out:
# Collecting feedparser
#   Using cached https://files.pythonhosted.org/packages/91/d8/7d37fec71ff7c9dbcdd80d2b48bcdd86d6af502156fc93846fb0102cb2c4/feedparser-5.2.1.tar.bz2
# Building wheels for collected packages: feedparser
#   Building wheel for feedparser (setup.py) ... done
#   Stored in directory: /Users/liviaclarete/Library/Caches/pip/wheels/8c/69/b7/f52763c41c5471df57703a0ef718a32a5e81ee35dcf6d4f97f
# Successfully built feedparser
# Installing collected packages: feedparser
# Successfully installed feedparser-5.2.1

# %%
# import feedparser
import feedparser

# %% [markdown]
# ### 1. Use feedparser to parse the following RSS feed URL.

# %%
url = 'http://feeds.feedburner.com/oreilly/radar/atom'

# %%
# importing parse() from feedparser passing the url as an argument
feed_oreilly = feedparser.parse(url)

# %%
# feed type
type(feed_oreilly)
# Out:
# feedparser.FeedParserDict

# %%
# note the object is a dict
feed_oreilly
# Out:
# {'feed': {'title': "All - O'Reilly Media",
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': "All - O'Reilly Media"},
#   'id': 'https://www.oreilly.com',
#   'guidislink': True,
#   'link': 'https://www.oreilly.com',
#   'updated': '2019-09-04T14:38:31Z',
#   'updated_parsed': time.struct_time(tm_year=2019, tm_mon=9, tm_mday=4, tm_hour=14, tm_min=38, tm_sec=31, tm_wday=2, tm_yday=247, tm_isdst=0),
#   'subtitle': 'All of our Ideas and Learning material from all of our topics.',
#   'subtitle_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#    'value': 'All of our Ideas and Learning material from all of our topics.'},
#   'links': [{'href': 'https://www.oreilly.com',
#     'rel': 'alternate',
#     'type': 'text/html'},
#    {'rel': 'self',
#     'type': 'application/atom+xml',
#     'href': 'http://feeds.feedburner.com/oreilly/radar/atom'},
#    {'rel': 'hub',
#     'href': 'http://pubsubhubbub.appspot.com/',
#     'type': 'text/html'}],
#   'authors': [{'name': "O'Reilly Media"}],
#   'author_detail': {'name': "O'Reilly Media"},
#   'author': "O'Reilly Media",
#   'feedburner_info': {'uri': 'oreilly/radar/atom'},
#   'geo_lat': '38.393314',
#   'geo_long': '-122.836667',
#   'feedburner_emailserviceid': 'oreilly/radar/atom',
#   'feedburner_feedburnerhostname': 'https://feedburner.google.com'},
#  'entries': [{'title': 'New live online training courses',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'New live online training courses'},
#    'updated': '2019-09-04T12:10:00Z',
#    'updated_parsed': time.struct_time(tm_year=2019, tm_mon=9, tm_mday=4, tm_hour=12, tm_min=10, tm_sec=0, tm_wday=2, tm_yday=247, tm_isdst=0),
#    'id': 'tag:www.oreilly.com,2019-09-04:/ideas/new-live-online-training-courses',
#    'guidislink': True,
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/Q8JFXuBynxs/new-live-online-training-courses',
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p><img src=\'https://d3ucjech6zwjp8.cloudfront.net/600x450/student-studing-lg-4b007e0a2faeb3c285af467223dbe6bd.jpg\'/></p><p><em>Get hands-on training in machine learning, TensorFlow, blockchain, Python, cybersecurity, and many other topics.</em></p><p>Learn new topics and refine your skills with <a href="https://learning.oreilly.com/live-training/">more than 165 new live online training courses we opened up for September and October</a> on the O\'Reilly online learning platform.</p>\r\n\r\n<h2>AI and machine learning</h2>\r\n\r\n<p><em><a href="https://learning.oreilly.com/live-training/courses/machine-learning-with-the-tidyverse-in-r/0636920326045/">Machine Learning with the Tidyverse in R</a></em>, September 19</p>\r\n<p><em><a href="https://learning.oreilly.com/live-training/courses/deep-learning-with-pytorch/0636920322795/">Deep Learning with PyTorch</a></em>, October 1</p>\r\n<p><em><a href="https://learning.oreilly.com/live-training/courses/deploy-machine-learning-projects-in-production-with-open-standard-models/0636920318347/">Deploy Machine Learning Projects in Production with Open Standard Models</a></em>, October 1</p>\r\n<p><em><a href="https://learning.oreilly.com/live-training/courses/building-ai-ml-applications-on-google-cloud-platform/0636920326489/">Building AI &amp; ML Applications on Google Cloud Platform</a></em>, October 2</p>\r\n<p><em><a href="https://learning.oreilly.com/live-training/courses/introduction-to-tensorflow-20/0636920311898/">Introduction to TensorFlow 2.0</a></em>, October 7</p>\r\n<p><em><a href="https://learning.oreilly.com/live-training/courses/deep-learning-for-natural-language-processing-nlp/0636920322702/">Deep Learning for Natural Language Processing (NLP)</a></em>, October 9</p>\r\n<p><em><a href="https://learning.oreilly.com/live-training/courses/hands-on-adversarial-machine-learning/0636920285342/">Hands-on adversarial machine learning</a></em>, October 22</p>\r\n<p><em><a href="https://learning.oreilly.com/live-training/courses/introduction-to-ai-on-google-cloud/0636920310884/">Introduction to AI on Google Cloud</a></em>, October 29</p>\r\n<p><em><a href="https://learning.oreilly.com/live-training/courses/intermediate-natural-language-processing-nlp/0636920326717/">Intermediate Natural Language Processing (NLP)</a></em>, October 29</p>\r\n<p><em><a href="https://learning.oreilly.com/live-training/courses/a-practical-introduction-to-machine-learning/0636920290285/">A Practical Introduction to Machine Learning</a></em>, October 30</p>\r\n<p><em><a href="https://learning.oreilly.com/live-training/courses/hands-on-machine-learning-with-python-classification-and-regression/0636920324324/">Hands-on Machine Learning with Python: Classification and Regression</a></em>, October 30</p>\r\n<p><em><a href="https://learning.oreilly.com/live-training/courses/introducing-machine-learning-with-amazon-sagemaker/0636920329114/">Introducing Machine Learning with Amazon SageMaker</a></em>, October 30</p>\r\n<p><em><a href="https://learning.oreilly.com/live-training/courses/hands-on-machine-learning-with-python-clustering-dimension-reduction-and-time-series-analysis/0636920324423/">Hands-on Machine Learning with Python: Clustering, Dimension Reduction, and Time Series Analysis</a></em>, October 31</p>\r\n<p><em><a href="https://learning.oreilly.com/live-training/courses/artificial-intelligence-ai-for-business/0636920320401/">Artificial Intelligence: AI For Business</a></em>, November 5</p>\r\n<p><em><a href="https://learning.oreilly.com/live-training/courses/fundamentals-of-ai-algorithms-in-90-minutes/0636920326465/">Fundamentals of AI Algorithms in 90 minutes</a></em>, November 20</p>\r\n\r\n\r\n<h2>Blockchain</h2>\r\n\r\n<p><em><a href="https://learning.oreilly.com/live-training/courses/blockchain-and-cryptocurrency-essentials/0636920331797/">Blockchain and Cryptocurrency Essentials</a></em>, October 28</p>\r\n\r\n\r\n<h2>Business</h2>\r\n\r\n<p><em><a href="https://learning.oreilly ...
#    'summary': '<p><img src=\'https://d3ucjech6zwjp8.cloudfront.net/600x450/student-studing-lg-4b007e0a2faeb3c285af467223dbe6bd.jpg\'/></p><p><em>Get hands-on training in machine learning, TensorFlow, blockchain, Python, cybersecurity, and many other topics.</em></p><p>Learn new topics and refine your skills with <a href="https://learning.oreilly.com/live-training/">more than 165 new live online training courses we opened up for September and October</a> on the O\'Reilly online learning platform.</p>\r\n\r\n<h2>AI and machine learning</h2>\r\n\r\n<p><em><a href="https://learning.oreilly.com/live-training/courses/machine-learning-with-the-tidyverse-in-r/0636920326045/">Machine Learning with the Tidyverse in R</a></em>, September 19</p>\r\n<p><em><a href="https://learning.oreilly.com/live-training/courses/deep-learning-with-pytorch/0636920322795/">Deep Learning with PyTorch</a></em>, October 1</p>\r\n<p><em><a href="https://learning.oreilly.com/live-training/courses/deploy-machine-learning-projects-in-production-with-open-standard-models/0636920318347/">Deploy Machine Learning Projects in Production with Open Standard Models</a></em>, October 1</p>\r\n<p><em><a href="https://learning.oreilly.com/live-training/courses/building-ai-ml-applications-on-google-cloud-platform/0636920326489/">Building AI &amp; ML Applications on Google Cloud Platform</a></em>, October 2</p>\r\n<p><em><a href="https://learning.oreilly.com/live-training/courses/introduction-to-tensorflow-20/0636920311898/">Introduction to TensorFlow 2.0</a></em>, October 7</p>\r\n<p><em><a href="https://learning.oreilly.com/live-training/courses/deep-learning-for-natural-language-processing-nlp/0636920322702/">Deep Learning for Natural Language Processing (NLP)</a></em>, October 9</p>\r\n<p><em><a href="https://learning.oreilly.com/live-training/courses/hands-on-adversarial-machine-learning/0636920285342/">Hands-on adversarial machine learning</a></em>, October 22</p>\r\n<p><em><a href="https://learning.oreilly.com/live-training/courses/introduction-to-ai-on-google-cloud/0636920310884/">Introduction to AI on Google Cloud</a></em>, October 29</p>\r\n<p><em><a href="https://learning.oreilly.com/live-training/courses/intermediate-natural-language-processing-nlp/0636920326717/">Intermediate Natural Language Processing (NLP)</a></em>, October 29</p>\r\n<p><em><a href="https://learning.oreilly.com/live-training/courses/a-practical-introduction-to-machine-learning/0636920290285/">A Practical Introduction to Machine Learning</a></em>, October 30</p>\r\n<p><em><a href="https://learning.oreilly.com/live-training/courses/hands-on-machine-learning-with-python-classification-and-regression/0636920324324/">Hands-on Machine Learning with Python: Classification and Regression</a></em>, October 30</p>\r\n<p><em><a href="https://learning.oreilly.com/live-training/courses/introducing-machine-learning-with-amazon-sagemaker/0636920329114/">Introducing Machine Learning with Amazon SageMaker</a></em>, October 30</p>\r\n<p><em><a href="https://learning.oreilly.com/live-training/courses/hands-on-machine-learning-with-python-clustering-dimension-reduction-and-time-series-analysis/0636920324423/">Hands-on Machine Learning with Python: Clustering, Dimension Reduction, and Time Series Analysis</a></em>, October 31</p>\r\n<p><em><a href="https://learning.oreilly.com/live-training/courses/artificial-intelligence-ai-for-business/0636920320401/">Artificial Intelligence: AI For Business</a></em>, November 5</p>\r\n<p><em><a href="https://learning.oreilly.com/live-training/courses/fundamentals-of-ai-algorithms-in-90-minutes/0636920326465/">Fundamentals of AI Algorithms in 90 minutes</a></em>, November 20</p>\r\n\r\n\r\n<h2>Blockchain</h2>\r\n\r\n<p><em><a href="https://learning.oreilly.com/live-training/courses/blockchain-and-cryptocurrency-essentials/0636920331797/">Blockchain and Cryptocurrency Essentials</a></em>, October 28</p>\r\n\r\n\r\n<h2>Business</h2>\r\n\r\n<p><em><a href="https://learning.oreilly ...
#    'links': [{'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/Q8JFXuBynxs/new-live-online-training-courses',
#      'rel': 'alternate',
#      'type': 'text/html'}],
#    'feedburner_origlink': 'https://www.oreilly.com/ideas/new-live-online-training-courses'},
#   {'title': 'Four short links: 4 September 2019',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Four short links: 4 September 2019'},
#    'updated': '2019-09-04T11:45:00Z',
#    'updated_parsed': time.struct_time(tm_year=2019, tm_mon=9, tm_mday=4, tm_hour=11, tm_min=45, tm_sec=0, tm_wday=2, tm_yday=247, tm_isdst=0),
#    'id': 'tag:www.oreilly.com,2019-09-04:/ideas/four-short-links-4-september-2019',
#    'guidislink': True,
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/WCyIyW85W2c/four-short-links-4-september-2019',
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p><em>iOS Security, IoT Wi-Fi Attacks, Interactive SSH Programs, and Replacing Faces in Video</em></p><ol>\r\n<li>\r\n<a href="https://twitter.com/thegrugq/status/1168983377082572803">A Secured Android Phone is Safer Than an iOS Device</a> (thegrugq) -- <i>The iOS ecosystem is a monoculture, where security is tied to latest hardware and latest software. If you’re behind on either one? Vulnerable to commercial exploit chains. Multiple chains. Android has become incredibly more resilient, and due to diversity, much harder to attack.</i>\r\n</li>\r\n<li>\r\n<a href="https://github.com/Matheus-Garbelini/esp32_esp8266_attacks">ESP32 and ESP8266 Attacks</a> -- <i>This repository demonstrates three Wi-Fi attacks against the popular ESP32/8266 IoT devices.</i> They\'re the go-to Wi-Fi chips for Arduino-type projects, and thus are in a startlingly large number of IoT devices.</li>\r\n<li>\r\n<a href="https://drewdevault.com/2019/09/02/Interactive-SSH-programs.html">Building Interactive SSH Programs</a> -- <i>Writing interactive SSH applications is actually pretty easy, but it does require some knowledge of the pieces involved and a little bit of general Unix literacy.</i>\r\n</li>\r\n<li>\r\n<a href="https://github.com/iperov/DeepFaceLab">DeepFaceLab</a> -- open source tool that uses machine learning to replace faces in video.</li>\r\n</ol>\r\n<p>Continue reading <a href=\'https://www.oreilly.com/ideas/four-short-links-4-september-2019\'>Four short links: 4 September 2019.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/WCyIyW85W2c" height="1" width="1" alt=""/>'}],
#    'summary': '<p><em>iOS Security, IoT Wi-Fi Attacks, Interactive SSH Programs, and Replacing Faces in Video</em></p><ol>\r\n<li>\r\n<a href="https://twitter.com/thegrugq/status/1168983377082572803">A Secured Android Phone is Safer Than an iOS Device</a> (thegrugq) -- <i>The iOS ecosystem is a monoculture, where security is tied to latest hardware and latest software. If you’re behind on either one? Vulnerable to commercial exploit chains. Multiple chains. Android has become incredibly more resilient, and due to diversity, much harder to attack.</i>\r\n</li>\r\n<li>\r\n<a href="https://github.com/Matheus-Garbelini/esp32_esp8266_attacks">ESP32 and ESP8266 Attacks</a> -- <i>This repository demonstrates three Wi-Fi attacks against the popular ESP32/8266 IoT devices.</i> They\'re the go-to Wi-Fi chips for Arduino-type projects, and thus are in a startlingly large number of IoT devices.</li>\r\n<li>\r\n<a href="https://drewdevault.com/2019/09/02/Interactive-SSH-programs.html">Building Interactive SSH Programs</a> -- <i>Writing interactive SSH applications is actually pretty easy, but it does require some knowledge of the pieces involved and a little bit of general Unix literacy.</i>\r\n</li>\r\n<li>\r\n<a href="https://github.com/iperov/DeepFaceLab">DeepFaceLab</a> -- open source tool that uses machine learning to replace faces in video.</li>\r\n</ol>\r\n<p>Continue reading <a href=\'https://www.oreilly.com/ideas/four-short-links-4-september-2019\'>Four short links: 4 September 2019.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/WCyIyW85W2c" height="1" width="1" alt=""/>',
#    'links': [{'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/WCyIyW85W2c/four-short-links-4-september-2019',
#      'rel': 'alternate',
#      'type': 'text/html'}],
#    'authors': [{'name': 'Nat Torkington'}],
#    'author_detail': {'name': 'Nat Torkington'},
#    'author': 'Nat Torkington',
#    'feedburner_origlink': 'https://www.oreilly.com/ideas/four-short-links-4-september-2019'},
#   {'title': 'How new tools in data and AI are being used in health care and medicine',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'How new tools in data and AI are being used in health care and medicine'},
#    'updated': '2019-09-03T17:05:00Z',
#    'updated_parsed': time.struct_time(tm_year=2019, tm_mon=9, tm_mday=3, tm_hour=17, tm_min=5, tm_sec=0, tm_wday=1, tm_yday=246, tm_isdst=0),
#    'id': 'tag:www.oreilly.com,2019-09-03:/ideas/how-new-tools-in-data-and-ai-are-being-used-in-health-care-and-medicine',
#    'guidislink': True,
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9_GTe6gNoxU/how-new-tools-in-data-and-ai-are-being-used-in-health-care-and-medicine',
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p><img src=\'https://d3ucjech6zwjp8.cloudfront.net/600x450/ai-ml-crystals-6b-1400x950-7660f743b8570f7920d10495187c4919.jpg\'/></p><p><em>An overview of applications of new tools for overcoming silos, and for creating and sharing high-quality data.</em></p><p>Artificial intelligence (AI) will have a huge impact on health care. It is currently moving out of the laboratory and into real-world applications for health care and medicine. <a href="http://www.112capital.com/perspectives">Many startups</a> are using modern data and AI technologies to tackle problems related to workflow optimization and automation, demand forecasting, treatment and care, diagnostics, drug discovery, personalized medicine, and many other areas. Some of these companies are beginning to speak publicly about their AI initiatives; our upcoming Artificial Intelligence conferences in San Jose and London have a strong roster of speakers who will describe applications of <a href="https://conferences.oreilly.com/artificial-intelligence/ai-ca/public/schedule/stopic/3332">AI in health and medicine</a>.</p>\r\n\r\n<p>AI’s transition to the real world can be challenging. This article highlights new projects and tools that can alleviate and address these challenges. We’re not trying to be comprehensive; our goal is to raise awareness of some of the bottlenecks that workers in health care and medicine will face as they adopt AI. We will focus on recent progress in foundational topics that the health care and medical communities care about: access to high-quality labeled data, developing ML models that cut across organizations, and data markets and networks.</p>\r\n\r\n<h2>AI’s footprint in health care</h2>\r\n\r\n<p>While it’s important to distinguish reality from hype (and there is a lot of hype), we see many companies making significant investments in health care. According to a 2019 World Intellectual Patent Office (WIPO) <a href="https://www.wipo.int/publications/en/details.jsp?id=4386">report</a>, "Life and Medical Sciences" is the third-highest field for patent applications (the top two are "Telecommunications" and "Transportation"), with roughly 40,000 patent applications:</p>\r\n\r\n<figure id="id-RlWiz"><img alt="Number of patent families for application field categories" class="iimageswipo-application-fieldpng" src="https://d3ansictanv2wj.cloudfront.net/WIPO-Application-Field-26d735842bd9b61b48d93b4dd8648dc5.png">\r\n<figcaption><span class="label">Figure 1. </span>A <a href="https://www.wipo.int/publications/en/details.jsp?id=4386">2019 WIPO Study</a> shows the number of patent families by application field. A patent may refer to more than one category or subcategory. Image by Ben Lorica.</figcaption>\r\n</figure>\r\n\r\n<p>This focus on AI is important for several reasons. First, in most countries (and in <a href="https://news.aamc.org/press-releases/article/workforce_report_shortage_04112018/">many parts of the US</a>), there is a shortage of doctors. Using AI to make a first pass at <a href="https://www.newscientist.com/article/2193361-ai-can-diagnose-childhood-illnesses-better-than-some-doctors/">diagnostics</a> can reduce the workload on medical staff, who are already overburdened. Second, there’s a lot of evidence that machine learning (ML) can augment medical professionals, including <a href="https://www.ncbi.nlm.nih.gov/pubmed/30325645">radiologists</a>. Third, interest in continual health monitoring, using consumer devices like the Apple Watch, is exploding, but don’t expect a doctor or a nurse to be monitoring your data feed. If you’re about to have a heart attack or a stroke, it will be AI that analyzes the data, notes the abnormality, and generates the alarm. In health care, as in other industries, AI is the only way to scale services to match demand.</p>\r\n\r\n<h2>Data quality and labeling</h2>\r\n\r\n<p>Since the first days of the Strata Data Conference, we’ve been saying that most of the work in data isn’t playing with fancy a ...
#    'summary': '<p><img src=\'https://d3ucjech6zwjp8.cloudfront.net/600x450/ai-ml-crystals-6b-1400x950-7660f743b8570f7920d10495187c4919.jpg\'/></p><p><em>An overview of applications of new tools for overcoming silos, and for creating and sharing high-quality data.</em></p><p>Artificial intelligence (AI) will have a huge impact on health care. It is currently moving out of the laboratory and into real-world applications for health care and medicine. <a href="http://www.112capital.com/perspectives">Many startups</a> are using modern data and AI technologies to tackle problems related to workflow optimization and automation, demand forecasting, treatment and care, diagnostics, drug discovery, personalized medicine, and many other areas. Some of these companies are beginning to speak publicly about their AI initiatives; our upcoming Artificial Intelligence conferences in San Jose and London have a strong roster of speakers who will describe applications of <a href="https://conferences.oreilly.com/artificial-intelligence/ai-ca/public/schedule/stopic/3332">AI in health and medicine</a>.</p>\r\n\r\n<p>AI’s transition to the real world can be challenging. This article highlights new projects and tools that can alleviate and address these challenges. We’re not trying to be comprehensive; our goal is to raise awareness of some of the bottlenecks that workers in health care and medicine will face as they adopt AI. We will focus on recent progress in foundational topics that the health care and medical communities care about: access to high-quality labeled data, developing ML models that cut across organizations, and data markets and networks.</p>\r\n\r\n<h2>AI’s footprint in health care</h2>\r\n\r\n<p>While it’s important to distinguish reality from hype (and there is a lot of hype), we see many companies making significant investments in health care. According to a 2019 World Intellectual Patent Office (WIPO) <a href="https://www.wipo.int/publications/en/details.jsp?id=4386">report</a>, "Life and Medical Sciences" is the third-highest field for patent applications (the top two are "Telecommunications" and "Transportation"), with roughly 40,000 patent applications:</p>\r\n\r\n<figure id="id-RlWiz"><img alt="Number of patent families for application field categories" class="iimageswipo-application-fieldpng" src="https://d3ansictanv2wj.cloudfront.net/WIPO-Application-Field-26d735842bd9b61b48d93b4dd8648dc5.png">\r\n<figcaption><span class="label">Figure 1. </span>A <a href="https://www.wipo.int/publications/en/details.jsp?id=4386">2019 WIPO Study</a> shows the number of patent families by application field. A patent may refer to more than one category or subcategory. Image by Ben Lorica.</figcaption>\r\n</figure>\r\n\r\n<p>This focus on AI is important for several reasons. First, in most countries (and in <a href="https://news.aamc.org/press-releases/article/workforce_report_shortage_04112018/">many parts of the US</a>), there is a shortage of doctors. Using AI to make a first pass at <a href="https://www.newscientist.com/article/2193361-ai-can-diagnose-childhood-illnesses-better-than-some-doctors/">diagnostics</a> can reduce the workload on medical staff, who are already overburdened. Second, there’s a lot of evidence that machine learning (ML) can augment medical professionals, including <a href="https://www.ncbi.nlm.nih.gov/pubmed/30325645">radiologists</a>. Third, interest in continual health monitoring, using consumer devices like the Apple Watch, is exploding, but don’t expect a doctor or a nurse to be monitoring your data feed. If you’re about to have a heart attack or a stroke, it will be AI that analyzes the data, notes the abnormality, and generates the alarm. In health care, as in other industries, AI is the only way to scale services to match demand.</p>\r\n\r\n<h2>Data quality and labeling</h2>\r\n\r\n<p>Since the first days of the Strata Data Conference, we’ve been saying that most of the work in data isn’t playing with fancy a ...
#    'links': [{'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/9_GTe6gNoxU/how-new-tools-in-data-and-ai-are-being-used-in-health-care-and-medicine',
#      'rel': 'alternate',
#      'type': 'text/html'}],
#    'authors': [{'name': 'Mike Loukides, Ben Lorica'}],
#    'author_detail': {'name': 'Mike Loukides, Ben Lorica'},
#    'author': 'Mike Loukides, Ben Lorica',
#    'feedburner_origlink': 'https://www.oreilly.com/ideas/how-new-tools-in-data-and-ai-are-being-used-in-health-care-and-medicine'},
#   {'title': 'Four short links: 3 September 2019',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Four short links: 3 September 2019'},
#    'updated': '2019-09-03T10:50:00Z',
#    'updated_parsed': time.struct_time(tm_year=2019, tm_mon=9, tm_mday=3, tm_hour=10, tm_min=50, tm_sec=0, tm_wday=1, tm_yday=246, tm_isdst=0),
#    'id': 'tag:www.oreilly.com,2019-09-03:/ideas/four-short-links-3-september-2019',
#    'guidislink': True,
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/t0ywqHTDVfM/four-short-links-3-september-2019',
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p><em>Crummy Translations, Synthetic Data Sets, Building Communities, and Deleting Accounts</em></p><ol>\r\n<li>\r\n<a href="https://arxiv.org/abs/1908.11425">Classifying Topics in Speech When All You Have is Crummy Translations</a> -- <i>While the translations are poor, they are still good enough to correctly classify one-minute speech segments over 70% of the time—a 20% improvement over a majority-class baseline. Such a system might be useful for humanitarian applications like crisis response, where incoming speech must be quickly assessed for further action.</i>\r\n</li>\r\n<li>\r\n<a href="https://psyarxiv.com/dmfb3/">Synthetic Data Sets: A Non-Technical Primer For The Biobehavioral Sciences</a> -- respecting confidentiality by generating data sets that <i>preserve their statistical properties and relationships between variables</i> while varying the specific data.</li>\r\n<li>\r\n<a href="https://gettogetherbook.com">Get Together</a> -- a book with how-to advice from real community builders, from the team behind <a href="https://gettogether.fm/">The Get Together podcast</a>.</li>\r\n<li>\r\n<a href="https://backgroundchecks.org/justdeleteme/">Just Delete Me</a> -- <i>A directory of direct links to delete your account from web services.</i>\r\n</li>\r\n</ol>\r\n<p>Continue reading <a href=\'https://www.oreilly.com/ideas/four-short-links-3-september-2019\'>Four short links: 3 September 2019.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/t0ywqHTDVfM" height="1" width="1" alt=""/>'}],
#    'summary': '<p><em>Crummy Translations, Synthetic Data Sets, Building Communities, and Deleting Accounts</em></p><ol>\r\n<li>\r\n<a href="https://arxiv.org/abs/1908.11425">Classifying Topics in Speech When All You Have is Crummy Translations</a> -- <i>While the translations are poor, they are still good enough to correctly classify one-minute speech segments over 70% of the time—a 20% improvement over a majority-class baseline. Such a system might be useful for humanitarian applications like crisis response, where incoming speech must be quickly assessed for further action.</i>\r\n</li>\r\n<li>\r\n<a href="https://psyarxiv.com/dmfb3/">Synthetic Data Sets: A Non-Technical Primer For The Biobehavioral Sciences</a> -- respecting confidentiality by generating data sets that <i>preserve their statistical properties and relationships between variables</i> while varying the specific data.</li>\r\n<li>\r\n<a href="https://gettogetherbook.com">Get Together</a> -- a book with how-to advice from real community builders, from the team behind <a href="https://gettogether.fm/">The Get Together podcast</a>.</li>\r\n<li>\r\n<a href="https://backgroundchecks.org/justdeleteme/">Just Delete Me</a> -- <i>A directory of direct links to delete your account from web services.</i>\r\n</li>\r\n</ol>\r\n<p>Continue reading <a href=\'https://www.oreilly.com/ideas/four-short-links-3-september-2019\'>Four short links: 3 September 2019.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/t0ywqHTDVfM" height="1" width="1" alt=""/>',
#    'links': [{'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/t0ywqHTDVfM/four-short-links-3-september-2019',
#      'rel': 'alternate',
#      'type': 'text/html'}],
#    'authors': [{'name': 'Nat Torkington'}],
#    'author_detail': {'name': 'Nat Torkington'},
#    'author': 'Nat Torkington',
#    'feedburner_origlink': 'https://www.oreilly.com/ideas/four-short-links-3-september-2019'},
#   {'title': 'Four short links: 2 September 2019',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Four short links: 2 September 2019'},
#    'updated': '2019-09-02T13:35:00Z',
#    'updated_parsed': time.struct_time(tm_year=2019, tm_mon=9, tm_mday=2, tm_hour=13, tm_min=35, tm_sec=0, tm_wday=0, tm_yday=245, tm_isdst=0),
#    'id': 'tag:www.oreilly.com,2019-09-02:/ideas/four-short-links-2-september-2019',
#    'guidislink': True,
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/1gCSldHrquQ/four-short-links-2-september-2019',
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p><em>Enigma Simulator, Robot Startups, Code as Type, and Conversational Modeling</em></p><ol>\r\n<li>\r\n<a href="https://observablehq.com/@tmcw/enigma-machine">Visual Enigma Machine Simulator</a> -- this is the triple threat: interesting, of historic interest, and PURTY. (via <a href="https://twitter.com/tmcw/status/1167574798303543296">Tom MacWright</a>)</li>\r\n<li>\r\n<a href="https://www.youtube.com/watch?v=iW0dA0fLtXI">Move Fast and (Don’t) Break Things: Commercializing Robotics at the Speed of Venture Capital</a> (YouTube) -- interesting talk from a conference whose theme was "Notable Failures."</li>\r\n<li>\r\n<a href="https://github.com/cmiscm/leonsans">Leon Sans</a> -- <i>a geometric sans-serif typeface made with code</i>. It draws on an HTML Canvas so you can futz with the typeface yourself to get nifty effects. The demos are cool.</li>\r\n<li>\r\n<a href="https://www.microsoft.com/en-us/research/project/microsoft-icecaps/">Microsoft Icecaps</a> -- <i>an open source toolkit with a focus on conversational modeling</i>.</li>\r\n</ol>\r\n<p>Continue reading <a href=\'https://www.oreilly.com/ideas/four-short-links-2-september-2019\'>Four short links: 2 September 2019.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/1gCSldHrquQ" height="1" width="1" alt=""/>'}],
#    'summary': '<p><em>Enigma Simulator, Robot Startups, Code as Type, and Conversational Modeling</em></p><ol>\r\n<li>\r\n<a href="https://observablehq.com/@tmcw/enigma-machine">Visual Enigma Machine Simulator</a> -- this is the triple threat: interesting, of historic interest, and PURTY. (via <a href="https://twitter.com/tmcw/status/1167574798303543296">Tom MacWright</a>)</li>\r\n<li>\r\n<a href="https://www.youtube.com/watch?v=iW0dA0fLtXI">Move Fast and (Don’t) Break Things: Commercializing Robotics at the Speed of Venture Capital</a> (YouTube) -- interesting talk from a conference whose theme was "Notable Failures."</li>\r\n<li>\r\n<a href="https://github.com/cmiscm/leonsans">Leon Sans</a> -- <i>a geometric sans-serif typeface made with code</i>. It draws on an HTML Canvas so you can futz with the typeface yourself to get nifty effects. The demos are cool.</li>\r\n<li>\r\n<a href="https://www.microsoft.com/en-us/research/project/microsoft-icecaps/">Microsoft Icecaps</a> -- <i>an open source toolkit with a focus on conversational modeling</i>.</li>\r\n</ol>\r\n<p>Continue reading <a href=\'https://www.oreilly.com/ideas/four-short-links-2-september-2019\'>Four short links: 2 September 2019.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/1gCSldHrquQ" height="1" width="1" alt=""/>',
#    'links': [{'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/1gCSldHrquQ/four-short-links-2-september-2019',
#      'rel': 'alternate',
#      'type': 'text/html'}],
#    'authors': [{'name': 'Nat Torkington'}],
#    'author_detail': {'name': 'Nat Torkington'},
#    'author': 'Nat Torkington',
#    'feedburner_origlink': 'https://www.oreilly.com/ideas/four-short-links-2-september-2019'},
#   {'title': 'Four short links: 30 August 2019',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Four short links: 30 August 2019'},
#    'updated': '2019-08-30T11:00:00Z',
#    'updated_parsed': time.struct_time(tm_year=2019, tm_mon=8, tm_mday=30, tm_hour=11, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=242, tm_isdst=0),
#    'id': 'tag:www.oreilly.com,2019-08-30:/ideas/four-short-links-30-august-2019',
#    'guidislink': True,
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/_f-4N36v5yo/four-short-links-30-august-2019',
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p><em>Multi-Language Teams, AI Release Models, Security Myth, and The Internet is for End Users</em></p><ol>\r\n<li>\r\n<a href="https://www.skmurphy.com/blog/2019/08/06/lessons-from-working-with-teams-who-speak-english-as-a-second-language/">Lessons From Working With Teams Who Speak English as a Second Language</a> -- <i>We normally “take notes in public” by writing down key points in a shared document or chat. One of us will act as a contemporaneous note taker, capturing key points that anyone makes so that everyone can read the gist in addition to hearing it. This “real time subtitles” approach also communicates that we are actively listening and if we have misunderstood something, or they realize they misspoke and want to rephrase, then they can revisit that point immediately.</i> This can be a superpower.</li>\r\n<li>\r\n<a href="https://arxiv.org/pdf/1908.09203.pdf">Release Strategies and the Social Impacts of Language Models</a> -- a paper on OpenAI\'s strategy for releasing their language model, which is scary-good at generating text. <i>We chose a staged release process, releasing the smallest model in February, but withholding larger models due to concerns about the potential for misuse, such as generating fake news content, impersonating others in email, or automating abusive social media content production. We released the next model size in May as part of a staged release process. We are now releasing our 774 million parameter model.</i>\r\n</li>\r\n<li>\r\n<a href="https://www.schneier.com/blog/archives/2019/08/the_myth_of_con.html">The Myth of Consumer-Grade Security</a> (Bruce Schneier) -- <i>that distinction between military and consumer products largely doesn\'t exist. All of those "consumer products" Barr wants access to are used by government officials—heads of state, legislators, judges, military commanders, and everyone else—worldwide. They\'re used by election officials, police at all levels, nuclear power plant operators, CEOs, and human rights activists. They\'re critical to national security as well as personal security.</i>\r\n</li>\r\n<li>\r\n<a href="https://intarchboard.github.io/for-the-users/draft-iab-for-the-users.html">The Internet is for End Users</a> (IETF Draft) -- <i>As the internet increasingly mediates essential functions in societies, it has unavoidably become profoundly political; it has helped people overthrow governments and revolutionize social orders, control populations, collect data about individuals, and reveal secrets. It has created wealth for some individuals and companies while destroying others’. All of this raises the question: who do we go through the pain of gathering rough consensus and writing running code for?</i>\r\n</li>\r\n</ol>\r\n<p>Continue reading <a href=\'https://www.oreilly.com/ideas/four-short-links-30-august-2019\'>Four short links: 30 August 2019.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/_f-4N36v5yo" height="1" width="1" alt=""/>'}],
#    'summary': '<p><em>Multi-Language Teams, AI Release Models, Security Myth, and The Internet is for End Users</em></p><ol>\r\n<li>\r\n<a href="https://www.skmurphy.com/blog/2019/08/06/lessons-from-working-with-teams-who-speak-english-as-a-second-language/">Lessons From Working With Teams Who Speak English as a Second Language</a> -- <i>We normally “take notes in public” by writing down key points in a shared document or chat. One of us will act as a contemporaneous note taker, capturing key points that anyone makes so that everyone can read the gist in addition to hearing it. This “real time subtitles” approach also communicates that we are actively listening and if we have misunderstood something, or they realize they misspoke and want to rephrase, then they can revisit that point immediately.</i> This can be a superpower.</li>\r\n<li>\r\n<a href="https://arxiv.org/pdf/1908.09203.pdf">Release Strategies and the Social Impacts of Language Models</a> -- a paper on OpenAI\'s strategy for releasing their language model, which is scary-good at generating text. <i>We chose a staged release process, releasing the smallest model in February, but withholding larger models due to concerns about the potential for misuse, such as generating fake news content, impersonating others in email, or automating abusive social media content production. We released the next model size in May as part of a staged release process. We are now releasing our 774 million parameter model.</i>\r\n</li>\r\n<li>\r\n<a href="https://www.schneier.com/blog/archives/2019/08/the_myth_of_con.html">The Myth of Consumer-Grade Security</a> (Bruce Schneier) -- <i>that distinction between military and consumer products largely doesn\'t exist. All of those "consumer products" Barr wants access to are used by government officials—heads of state, legislators, judges, military commanders, and everyone else—worldwide. They\'re used by election officials, police at all levels, nuclear power plant operators, CEOs, and human rights activists. They\'re critical to national security as well as personal security.</i>\r\n</li>\r\n<li>\r\n<a href="https://intarchboard.github.io/for-the-users/draft-iab-for-the-users.html">The Internet is for End Users</a> (IETF Draft) -- <i>As the internet increasingly mediates essential functions in societies, it has unavoidably become profoundly political; it has helped people overthrow governments and revolutionize social orders, control populations, collect data about individuals, and reveal secrets. It has created wealth for some individuals and companies while destroying others’. All of this raises the question: who do we go through the pain of gathering rough consensus and writing running code for?</i>\r\n</li>\r\n</ol>\r\n<p>Continue reading <a href=\'https://www.oreilly.com/ideas/four-short-links-30-august-2019\'>Four short links: 30 August 2019.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/_f-4N36v5yo" height="1" width="1" alt=""/>',
#    'links': [{'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/_f-4N36v5yo/four-short-links-30-august-2019',
#      'rel': 'alternate',
#      'type': 'text/html'}],
#    'authors': [{'name': 'Nat Torkington'}],
#    'author_detail': {'name': 'Nat Torkington'},
#    'author': 'Nat Torkington',
#    'feedburner_origlink': 'https://www.oreilly.com/ideas/four-short-links-30-august-2019'},
#   {'title': 'Becoming a machine learning practitioner',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Becoming a machine learning practitioner'},
#    'updated': '2019-08-29T12:00:00Z',
#    'updated_parsed': time.struct_time(tm_year=2019, tm_mon=8, tm_mday=29, tm_hour=12, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=241, tm_isdst=0),
#    'id': 'tag:www.oreilly.com,2019-08-29:/ideas/becoming-a-machine-learning-practitioner',
#    'guidislink': True,
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/98rC8JnFmew/becoming-a-machine-learning-practitioner',
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p><img src=\'https://d3ucjech6zwjp8.cloudfront.net/600x450/binary_code_crop-db0c787ff08feea5fbc5dc062230f7b4.jpg\'/></p><p><em>The O’Reilly Data Show Podcast: Kesha Williams on how she added machine learning to her software developer toolkit.</em></p><p>In this episode of the <a href="https://www.oreilly.com/ideas/topics/oreilly-data-show-podcast">Data Show</a>, I speak with <a href="https://www.linkedin.com/in/java-rock-star-kesha/">Kesha Williams</a>, technical instructor at <a href="https://acloud.guru/">A Cloud Guru</a>, a training company focused on cloud computing. As a full stack web developer, Williams became intrigued by machine learning and started teaching herself the ML tools on Amazon Web Services. Fast forward to today, Williams has built some well-regarded Alexa skills, mastered ML services on AWS, and has now firmly added machine learning to her developer toolkit.</p><p>Continue reading <a href=\'https://www.oreilly.com/ideas/becoming-a-machine-learning-practitioner\'>Becoming a machine learning practitioner.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/98rC8JnFmew" height="1" width="1" alt=""/>'}],
#    'summary': '<p><img src=\'https://d3ucjech6zwjp8.cloudfront.net/600x450/binary_code_crop-db0c787ff08feea5fbc5dc062230f7b4.jpg\'/></p><p><em>The O’Reilly Data Show Podcast: Kesha Williams on how she added machine learning to her software developer toolkit.</em></p><p>In this episode of the <a href="https://www.oreilly.com/ideas/topics/oreilly-data-show-podcast">Data Show</a>, I speak with <a href="https://www.linkedin.com/in/java-rock-star-kesha/">Kesha Williams</a>, technical instructor at <a href="https://acloud.guru/">A Cloud Guru</a>, a training company focused on cloud computing. As a full stack web developer, Williams became intrigued by machine learning and started teaching herself the ML tools on Amazon Web Services. Fast forward to today, Williams has built some well-regarded Alexa skills, mastered ML services on AWS, and has now firmly added machine learning to her developer toolkit.</p><p>Continue reading <a href=\'https://www.oreilly.com/ideas/becoming-a-machine-learning-practitioner\'>Becoming a machine learning practitioner.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/98rC8JnFmew" height="1" width="1" alt=""/>',
#    'links': [{'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/98rC8JnFmew/becoming-a-machine-learning-practitioner',
#      'rel': 'alternate',
#      'type': 'text/html'}],
#    'authors': [{'name': 'Ben Lorica'}],
#    'author_detail': {'name': 'Ben Lorica'},
#    'author': 'Ben Lorica',
#    'feedburner_origlink': 'https://www.oreilly.com/ideas/becoming-a-machine-learning-practitioner'},
#   {'title': 'Four short links: 29 August 2019',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Four short links: 29 August 2019'},
#    'updated': '2019-08-29T11:30:00Z',
#    'updated_parsed': time.struct_time(tm_year=2019, tm_mon=8, tm_mday=29, tm_hour=11, tm_min=30, tm_sec=0, tm_wday=3, tm_yday=241, tm_isdst=0),
#    'id': 'tag:www.oreilly.com,2019-08-29:/ideas/four-short-links-29-august-2019',
#    'guidislink': True,
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/yUGx8TrxWJw/four-short-links-29-august-2019',
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p><em>Debugging a Scale Problem, Verifying Cryptographic Protocols, Remote Team Stress, and PAC-MAN Source</em></p><ol>\r\n<li>\r\n<a href="https://about.gitlab.com/2019/08/27/tyranny-of-the-clock/">6 Lessons we Learned When Debugging a Scaling Problem on GitLab.com</a> -- <i>When you choose specific non-default settings, leave a comment or link to documentation/issues as to why; future people will thank you.</i> This.</li>\r\n<li>\r\n<a href="https://verifpal.com/">Verifpal</a> -- <i>software for verifying the security of cryptographic protocols. Building upon contemporary research in symbolic formal verification, Verifpal’s main aim is to appeal more to real-world practitioners, students, and engineers without sacrificing comprehensive formal verification features.</i>\r\n</li>\r\n<li>\r\n<a href="https://humanmade.com/uploads/2016/11/dealing_with_the_causes_of_stress_in_remote_teams.pdf">Stress in Remote Teams</a> -- features a good list of the causes of stress in remote teams. The section on work-family conflict struck close to home (so to speak).</li>\r\n<li>\r\n<a href="https://atariwiki.org/wiki/Wiki.jsp?page=PAC-MAN">Atari PAC-MAN Source Code</a> -- original Atari 8-bit PAC-MAN source code. You can even compare versions with and without use of the macro assembler.</li>\r\n</ol>\r\n<p>Continue reading <a href=\'https://www.oreilly.com/ideas/four-short-links-29-august-2019\'>Four short links: 29 August 2019.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/yUGx8TrxWJw" height="1" width="1" alt=""/>'}],
#    'summary': '<p><em>Debugging a Scale Problem, Verifying Cryptographic Protocols, Remote Team Stress, and PAC-MAN Source</em></p><ol>\r\n<li>\r\n<a href="https://about.gitlab.com/2019/08/27/tyranny-of-the-clock/">6 Lessons we Learned When Debugging a Scaling Problem on GitLab.com</a> -- <i>When you choose specific non-default settings, leave a comment or link to documentation/issues as to why; future people will thank you.</i> This.</li>\r\n<li>\r\n<a href="https://verifpal.com/">Verifpal</a> -- <i>software for verifying the security of cryptographic protocols. Building upon contemporary research in symbolic formal verification, Verifpal’s main aim is to appeal more to real-world practitioners, students, and engineers without sacrificing comprehensive formal verification features.</i>\r\n</li>\r\n<li>\r\n<a href="https://humanmade.com/uploads/2016/11/dealing_with_the_causes_of_stress_in_remote_teams.pdf">Stress in Remote Teams</a> -- features a good list of the causes of stress in remote teams. The section on work-family conflict struck close to home (so to speak).</li>\r\n<li>\r\n<a href="https://atariwiki.org/wiki/Wiki.jsp?page=PAC-MAN">Atari PAC-MAN Source Code</a> -- original Atari 8-bit PAC-MAN source code. You can even compare versions with and without use of the macro assembler.</li>\r\n</ol>\r\n<p>Continue reading <a href=\'https://www.oreilly.com/ideas/four-short-links-29-august-2019\'>Four short links: 29 August 2019.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/yUGx8TrxWJw" height="1" width="1" alt=""/>',
#    'links': [{'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/yUGx8TrxWJw/four-short-links-29-august-2019',
#      'rel': 'alternate',
#      'type': 'text/html'}],
#    'authors': [{'name': 'Nat Torkington'}],
#    'author_detail': {'name': 'Nat Torkington'},
#    'author': 'Nat Torkington',
#    'feedburner_origlink': 'https://www.oreilly.com/ideas/four-short-links-29-august-2019'},
#   {'title': 'One simple chart: Who is interested in Apache Pulsar?',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'One simple chart: Who is interested in Apache Pulsar?'},
#    'updated': '2019-08-28T11:00:00Z',
#    'updated_parsed': time.struct_time(tm_year=2019, tm_mon=8, tm_mday=28, tm_hour=11, tm_min=0, tm_sec=0, tm_wday=2, tm_yday=240, tm_isdst=0),
#    'id': 'tag:www.oreilly.com,2019-08-28:/ideas/one-simple-chart-who-is-interested-in-apache-pulsar',
#    'guidislink': True,
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/XpvLu3evTxk/one-simple-chart-who-is-interested-in-apache-pulsar',
#    'content': [{'type': 'text/html',
# ...
#    'links': [{'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/HhKaIL6C2Ow/better-living-through-software',
#      'rel': 'alternate',
#      'type': 'text/html'}],
#    'authors': [{'name': 'Tiffani Bell'}],
#    'author_detail': {'name': 'Tiffani Bell'},
#    'author': 'Tiffani Bell',
#    'feedburner_origlink': 'https://www.oreilly.com/ideas/better-living-through-software'},
#   {'title': "Highlights from the O'Reilly Open Source Software Conference in Portland 2019",
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': "Highlights from the O'Reilly Open Source Software Conference in Portland 2019"},
#    'updated': '2019-07-17T20:00:00Z',
#    'updated_parsed': time.struct_time(tm_year=2019, tm_mon=7, tm_mday=17, tm_hour=20, tm_min=0, tm_sec=0, tm_wday=2, tm_yday=198, tm_isdst=0),
#    'id': 'tag:www.oreilly.com,2019-07-17:/ideas/highlights-from-oscon-2019',
#    'guidislink': True,
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/TwO4VtSQLjo/highlights-from-oscon-2019',
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p><img src=\'https://d3ucjech6zwjp8.cloudfront.net/600x450/hero-h-1400x950-34c6325967a4c3cf52ca414fbe91f069.jpg\'/></p><p><em>Experts explore the role open source software plays in fields as varied as machine learning, blockchain, disaster response, and more.</em></p><p>People from across the open source world came together in Portland, Ore. for the <a href="https://conferences.oreilly.com/oscon/oscon-or">O\'Reilly Open Source Software Conference (OSCON)</a>. Below you\'ll find links to highlights from the event.</p>\r\n\r\n<h2>The war for the soul of open source</h2>\r\n\r\n<p>Drawing on 13 years spent building the Chef community, Adam Jacob takes a deep dive into the soul of open source.</p>\r\n\r\n<ul>\r\n\t<li>Watch "<a href="https://www.oreilly.com/ideas/the-war-for-the-soul-of-open-source">The war for the soul of open source</a>"</li>\r\n</ul>\r\n\r\n<h2>Ask not what Brands™ can do for you</h2>\r\n\r\n<p>VM Brasseur discusses the help new companies need to become authentic members of the free and open source software community.</p>\r\n\r\n<ul>\r\n\t<li>Watch "<a href="https://www.oreilly.com/ideas/ask-not-what-brands-can-do-for-you">Ask not what Brands™ can do for you</a>"</li>\r\n</ul>\r\n\r\n<h2>Better living through software</h2>\r\n\r\n<p>Tiffani Bell shares three lessons she\'s learned exploring how technology can help the less fortunate.</p>\r\n\r\n<ul>\r\n\t<li>Watch "<a href="https://www.oreilly.com/ideas/better-living-through-software">Better living through software</a>"</li>\r\n</ul>\r\n\r\n<h2>O’Reilly Radar: Open source technology trends—What our users tell us</h2>\r\n\r\n<p>Using aggregate analysis of O’Reilly online learning content usage and search data, Roger Magoulas shares key insights that impact the technology tools ecosystem.</p>\r\n\r\n<ul>\r\n\t<li>Watch "<a href="https://www.oreilly.com/ideas/oreilly-radar-open-source-technology-trends-oscon-19">O’Reilly Radar: Open source technology trends—What our users tell us</a>"</li>\r\n</ul>\r\n\r\n<h2>The next age of open innovation</h2>\r\n\r\n<p>Alison McCauley looks at how blockchain technology offers new tools that can help extend the ethos of open innovation into new areas.</p>\r\n\r\n<ul>\r\n\t<li>Watch "<a href="https://www.oreilly.com/ideas/the-next-age-of-open-innovation">The next age of open innovation</a>"</li>\r\n</ul>\r\n\r\n<h2>Managing machines</h2>\r\n\r\n<p>Pete Skomoroch covers what you need to know as we shift from a world of deterministic programs to systems that give unpredictable results on ever-changing training data.</p>\r\n\r\n<ul>\r\n\t<li>Watch "<a href="https://www.oreilly.com/ideas/managing-machines">Managing machines</a>"</li>\r\n</ul>\r\n\r\n<h2>Open source force multipliers</h2>\r\n\r\n<p>Adrian Cockcroft says the most successful open-source-based businesses have turned their partners and developer communities into force multipliers for their own marketing and engineering teams.</p>\r\n\r\n<ul>\r\n\t<li>Watch "<a class="fse fs link" href="https://www.oreilly.com/ideas/open-source-force-multipliers">Open source force multipliers</a>"</li>\r\n</ul>\r\n\r\n<h2>Built to last: Building and growing open source communities</h2>\r\n\r\n<p>Kay Williams explores key lessons for building strong open source communities based on Microsoft’s real-world experience with Kubernetes and VSCode.</p>\r\n\r\n<ul>\r\n\t<li>Watch "<a href="https://www.oreilly.com/ideas/built-to-last-building-and-growing-open-source-communities">Built to last: Building and growing open source communities</a>"</li>\r\n</ul>\r\n\r\n<h2>The role of open source in mitigating natural disasters</h2>\r\n\r\n<p>Pedro Cruz and Brad Topol discuss Call for Code, a global developer competition that uses open source technologies to address natural disasters.</p>\r\n\r\n<ul>\r\n\t<li>Watch "<a href="https://www.oreilly.com/ideas/the-role-of-open-source-in-mitigating-natural-disasters">The role of open source in mitigating natural disasters</a>"</li>\r\n</ul>\r\n\ ...
#    'summary': '<p><img src=\'https://d3ucjech6zwjp8.cloudfront.net/600x450/hero-h-1400x950-34c6325967a4c3cf52ca414fbe91f069.jpg\'/></p><p><em>Experts explore the role open source software plays in fields as varied as machine learning, blockchain, disaster response, and more.</em></p><p>People from across the open source world came together in Portland, Ore. for the <a href="https://conferences.oreilly.com/oscon/oscon-or">O\'Reilly Open Source Software Conference (OSCON)</a>. Below you\'ll find links to highlights from the event.</p>\r\n\r\n<h2>The war for the soul of open source</h2>\r\n\r\n<p>Drawing on 13 years spent building the Chef community, Adam Jacob takes a deep dive into the soul of open source.</p>\r\n\r\n<ul>\r\n\t<li>Watch "<a href="https://www.oreilly.com/ideas/the-war-for-the-soul-of-open-source">The war for the soul of open source</a>"</li>\r\n</ul>\r\n\r\n<h2>Ask not what Brands™ can do for you</h2>\r\n\r\n<p>VM Brasseur discusses the help new companies need to become authentic members of the free and open source software community.</p>\r\n\r\n<ul>\r\n\t<li>Watch "<a href="https://www.oreilly.com/ideas/ask-not-what-brands-can-do-for-you">Ask not what Brands™ can do for you</a>"</li>\r\n</ul>\r\n\r\n<h2>Better living through software</h2>\r\n\r\n<p>Tiffani Bell shares three lessons she\'s learned exploring how technology can help the less fortunate.</p>\r\n\r\n<ul>\r\n\t<li>Watch "<a href="https://www.oreilly.com/ideas/better-living-through-software">Better living through software</a>"</li>\r\n</ul>\r\n\r\n<h2>O’Reilly Radar: Open source technology trends—What our users tell us</h2>\r\n\r\n<p>Using aggregate analysis of O’Reilly online learning content usage and search data, Roger Magoulas shares key insights that impact the technology tools ecosystem.</p>\r\n\r\n<ul>\r\n\t<li>Watch "<a href="https://www.oreilly.com/ideas/oreilly-radar-open-source-technology-trends-oscon-19">O’Reilly Radar: Open source technology trends—What our users tell us</a>"</li>\r\n</ul>\r\n\r\n<h2>The next age of open innovation</h2>\r\n\r\n<p>Alison McCauley looks at how blockchain technology offers new tools that can help extend the ethos of open innovation into new areas.</p>\r\n\r\n<ul>\r\n\t<li>Watch "<a href="https://www.oreilly.com/ideas/the-next-age-of-open-innovation">The next age of open innovation</a>"</li>\r\n</ul>\r\n\r\n<h2>Managing machines</h2>\r\n\r\n<p>Pete Skomoroch covers what you need to know as we shift from a world of deterministic programs to systems that give unpredictable results on ever-changing training data.</p>\r\n\r\n<ul>\r\n\t<li>Watch "<a href="https://www.oreilly.com/ideas/managing-machines">Managing machines</a>"</li>\r\n</ul>\r\n\r\n<h2>Open source force multipliers</h2>\r\n\r\n<p>Adrian Cockcroft says the most successful open-source-based businesses have turned their partners and developer communities into force multipliers for their own marketing and engineering teams.</p>\r\n\r\n<ul>\r\n\t<li>Watch "<a class="fse fs link" href="https://www.oreilly.com/ideas/open-source-force-multipliers">Open source force multipliers</a>"</li>\r\n</ul>\r\n\r\n<h2>Built to last: Building and growing open source communities</h2>\r\n\r\n<p>Kay Williams explores key lessons for building strong open source communities based on Microsoft’s real-world experience with Kubernetes and VSCode.</p>\r\n\r\n<ul>\r\n\t<li>Watch "<a href="https://www.oreilly.com/ideas/built-to-last-building-and-growing-open-source-communities">Built to last: Building and growing open source communities</a>"</li>\r\n</ul>\r\n\r\n<h2>The role of open source in mitigating natural disasters</h2>\r\n\r\n<p>Pedro Cruz and Brad Topol discuss Call for Code, a global developer competition that uses open source technologies to address natural disasters.</p>\r\n\r\n<ul>\r\n\t<li>Watch "<a href="https://www.oreilly.com/ideas/the-role-of-open-source-in-mitigating-natural-disasters">The role of open source in mitigating natural disasters</a>"</li>\r\n</ul>\r\n\ ...
#    'links': [{'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/TwO4VtSQLjo/highlights-from-oscon-2019',
#      'rel': 'alternate',
#      'type': 'text/html'}],
#    'authors': [{'name': 'Mac Slocum'}],
#    'author_detail': {'name': 'Mac Slocum'},
#    'author': 'Mac Slocum',
#    'feedburner_origlink': 'https://www.oreilly.com/ideas/highlights-from-oscon-2019'},
#   {'title': 'The role of open source in mitigating natural disasters',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'The role of open source in mitigating natural disasters'},
#    'updated': '2019-07-17T20:00:00Z',
#    'updated_parsed': time.struct_time(tm_year=2019, tm_mon=7, tm_mday=17, tm_hour=20, tm_min=0, tm_sec=0, tm_wday=2, tm_yday=198, tm_isdst=0),
#    'id': 'tag:www.oreilly.com,2019-07-17:/ideas/the-role-of-open-source-in-mitigating-natural-disasters',
#    'guidislink': True,
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/DN0K0LdDME8/the-role-of-open-source-in-mitigating-natural-disasters',
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p><img src=\'https://d3ucjech6zwjp8.cloudfront.net/600x450/radar-se-os-natural-disaster-crop-e4d65518ed0ed9eb259d6e1c2a04af95.jpg\'/></p><p><em>Pedro Cruz and Brad Topol discuss Call for Code, a global developer competition that uses open source technologies to address natural disasters.</em></p><p>Continue reading <a href=\'https://www.oreilly.com/ideas/the-role-of-open-source-in-mitigating-natural-disasters\'>The role of open source in mitigating natural disasters.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/DN0K0LdDME8" height="1" width="1" alt=""/>'}],
#    'summary': '<p><img src=\'https://d3ucjech6zwjp8.cloudfront.net/600x450/radar-se-os-natural-disaster-crop-e4d65518ed0ed9eb259d6e1c2a04af95.jpg\'/></p><p><em>Pedro Cruz and Brad Topol discuss Call for Code, a global developer competition that uses open source technologies to address natural disasters.</em></p><p>Continue reading <a href=\'https://www.oreilly.com/ideas/the-role-of-open-source-in-mitigating-natural-disasters\'>The role of open source in mitigating natural disasters.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/DN0K0LdDME8" height="1" width="1" alt=""/>',
#    'links': [{'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/DN0K0LdDME8/the-role-of-open-source-in-mitigating-natural-disasters',
#      'rel': 'alternate',
#      'type': 'text/html'}],
#    'authors': [{'name': 'Pedro Cruz, Brad Topol'}],
#    'author_detail': {'name': 'Pedro Cruz, Brad Topol'},
#    'author': 'Pedro Cruz, Brad Topol',
#    'feedburner_origlink': 'https://www.oreilly.com/ideas/the-role-of-open-source-in-mitigating-natural-disasters'},
#   {'title': 'Built to last: Building and growing open source communities',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#     'value': 'Built to last: Building and growing open source communities'},
#    'updated': '2019-07-17T20:00:00Z',
#    'updated_parsed': time.struct_time(tm_year=2019, tm_mon=7, tm_mday=17, tm_hour=20, tm_min=0, tm_sec=0, tm_wday=2, tm_yday=198, tm_isdst=0),
#    'id': 'tag:www.oreilly.com,2019-07-17:/ideas/built-to-last-building-and-growing-open-source-communities',
#    'guidislink': True,
#    'link': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/-4Lg-QA_OcY/built-to-last-building-and-growing-open-source-communities',
#    'content': [{'type': 'text/html',
#      'language': None,
#      'base': 'http://feeds.feedburner.com/oreilly/radar/atom',
#      'value': '<p><img src=\'https://d3ucjech6zwjp8.cloudfront.net/600x450/radar-se-built-to-last-crop-3ce1c2094460dcc3fe1156cb818db238.jpg\'/></p><p><em>Kay Williams explores key lessons for building strong open source communities based on Microsoft’s real-world experience with Kubernetes and VSCode.</em></p><p>Continue reading <a href=\'https://www.oreilly.com/ideas/built-to-last-building-and-growing-open-source-communities\'>Built to last: Building and growing open source communities.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/-4Lg-QA_OcY" height="1" width="1" alt=""/>'}],
#    'summary': '<p><img src=\'https://d3ucjech6zwjp8.cloudfront.net/600x450/radar-se-built-to-last-crop-3ce1c2094460dcc3fe1156cb818db238.jpg\'/></p><p><em>Kay Williams explores key lessons for building strong open source communities based on Microsoft’s real-world experience with Kubernetes and VSCode.</em></p><p>Continue reading <a href=\'https://www.oreilly.com/ideas/built-to-last-building-and-growing-open-source-communities\'>Built to last: Building and growing open source communities.</a></p><img src="http://feeds.feedburner.com/~r/oreilly/radar/atom/~4/-4Lg-QA_OcY" height="1" width="1" alt=""/>',
#    'links': [{'href': 'http://feedproxy.google.com/~r/oreilly/radar/atom/~3/-4Lg-QA_OcY/built-to-last-building-and-growing-open-source-communities',
#      'rel': 'alternate',
#      'type': 'text/html'}],
#    'authors': [{'name': 'Kay Williams'}],
#    'author_detail': {'name': 'Kay Williams'},
#    'author': 'Kay Williams',
#    'feedburner_origlink': 'https://www.oreilly.com/ideas/built-to-last-building-and-growing-open-source-communities'}],
#  'bozo': 0,
#  'headers': {'Content-Type': 'text/xml; charset=UTF-8',
#   'ETag': 'us2+E/MKdSqW/m2lb0veQQ5OF1s',
#   'Last-Modified': 'Wed, 04 Sep 2019 14:38:33 GMT',
#   'Content-Encoding': 'gzip',
#   'Transfer-Encoding': 'chunked',
#   'Date': 'Wed, 04 Sep 2019 14:44:51 GMT',
#   'Expires': 'Wed, 04 Sep 2019 14:44:51 GMT',
#   'Cache-Control': 'private, max-age=0',
#   'X-Content-Type-Options': 'nosniff',
#   'X-XSS-Protection': '1; mode=block',
#   'Server': 'GSE',
#   'Connection': 'close'},
#  'etag': 'us2+E/MKdSqW/m2lb0veQQ5OF1s',
#  'updated': 'Wed, 04 Sep 2019 14:38:33 GMT',
#  'updated_parsed': time.struct_time(tm_year=2019, tm_mon=9, tm_mday=4, tm_hour=14, tm_min=38, tm_sec=33, tm_wday=2, tm_yday=247, tm_isdst=0),
#  'href': 'http://feeds.feedburner.com/oreilly/radar/atom',
#  'status': 200,
#  'encoding': 'UTF-8',
#  'version': 'atom10',
#  'namespaces': {'': 'http://www.w3.org/2005/Atom',
#   'geo': 'http://www.w3.org/2003/01/geo/wgs84_pos#',
#   'feedburner': 'http://rssnamespace.org/feedburner/ext/1.0'}}

# %% [markdown]
# ### 2. Obtain a list of components (keys) that are available for this feed.

# %%
# we can access the keys elements by calling keys() over the the 
keys = list(feed_oreilly.keys())

# %%
len(keys)
# Out:
# 12

# %%
# 12 keys are listed
keys
# Out:
# ['feed',
#  'entries',
#  'bozo',
#  'headers',
#  'etag',
#  'updated',
#  'updated_parsed',
#  'href',
#  'status',
#  'encoding',
#  'version',
#  'namespaces']

# %% [markdown]
# ### 3. Obtain a list of components (keys) that are available for the *feed* component of this RSS feed.

# %%
# access the keys inside feed element
feed_key = list(feed_oreilly.feed.keys())

# %%
# print the of elements inside feed
feed_key
# Out:
# ['title',
#  'title_detail',
#  'id',
#  'guidislink',
#  'link',
#  'updated',
#  'updated_parsed',
#  'subtitle',
#  'subtitle_detail',
#  'links',
#  'authors',
#  'author_detail',
#  'author',
#  'feedburner_info',
#  'geo_lat',
#  'geo_long',
#  'feedburner_emailserviceid',
#  'feedburner_feedburnerhostname']

# %%
# we can call each one of this elements 
print(feed_oreilly.feed.title)
print(feed_oreilly.feed.author)
print(feed_oreilly.feed.geo_lat)
# Out:
# All - O'Reilly Media
# O'Reilly Media
# 38.393314

# %% [markdown]
# ### 4. Extract and print the feed title, subtitle, author, and link.

# %% [markdown]
# * Extract nested information in nested atributes

# %%
title = feed_oreilly.feed.title
subtitle = feed_oreilly.feed.subtitle
author = feed_oreilly.feed.author
link = feed_oreilly.feed.link

# %%
# print the atributes
print(f'Title:{title}, \nSubtitle:{subtitle}, \nAuthor:{author}, \nLink:{link}')
# Out:
# Title:All - O'Reilly Media,
# Subtitle:All of our Ideas and Learning material from all of our topics.,
# Author:O'Reilly Media,
# Link:https://www.oreilly.com

# %% [markdown]
# ### 5. Count the number of entries that are contained in this RSS feed.

# %%
# Print the number of entries
len(feed_oreilly.entries)
# Out:
# 60

# %% [markdown]
# ### 6. Obtain a list of components (keys) available for an entry.
#
# *Hint: Remember to index first before requesting the keys*

# %%
# select the first element from feed_oreilly.entries and call the keys() function
entries_key = feed_oreilly.entries[0].keys()

# %%
# convert the dict_keys into a list
entries_key = list(entries_key)

# %%
entries_key
# Out:
# ['title',
#  'title_detail',
#  'updated',
#  'updated_parsed',
#  'id',
#  'guidislink',
#  'link',
#  'content',
#  'summary',
#  'links',
#  'feedburner_origlink']

# %% [markdown]
# ### 7. Extract a list of entry titles.

# %% [markdown]
# * We need a for/loop to extract all nested titles within entries

# %%
# iterate through each element and return the 'title' from each entry
titles = [entry['title'] 
          for entry in feed_oreilly.entries]

# %%
titles
# Out:
# ['New live online training courses',
#  'Four short links: 4 September 2019',
#  'How new tools in data and AI are being used in health care and medicine',
#  'Four short links: 3 September 2019',
#  'Four short links: 2 September 2019',
#  'Four short links: 30 August 2019',
#  'Becoming a machine learning practitioner',
#  'Four short links: 29 August 2019',
#  'One simple chart: Who is interested in Apache Pulsar?',
#  'Four short links: 28 August 2019',
#  'Four short links: 27 August 2019',
#  'Four short links: 26 August 2019',
#  'How organizations are sharpening their skills to better understand and use AI',
#  'Four short links: 23 August 2019',
#  'Four short links: 22 August 2019',
#  'Four short links: 21 August 2019',
#  'Four short links: 20 August 2019',
#  'Four short links: 19 August 2019',
#  'Antitrust regulators are using the wrong tools to break up Big Tech',
#  'Labeling, transforming, and structuring training data sets for machine learning',
#  'Four short links: 15 August 2019',
#  'Four short links: 14 August 2019',
#  'Four short links: 13 August 2019',
#  'Blockchain solutions in enterprise',
#  'Four short links: 12 August 2019',
#  'Four short links: 9 August 2019',
#  'Got speech? These guidelines will help you get started building voice applications',
#  'Four short links: 8 August 2019',
#  'Four short links: 7 August 2019',
#  'Four short links: 6 August 2019',
#  'Four short links: 5 August 2019',
#  'Four short links: 2 August 2019',
#  'Make data science more useful',
#  'Taming chaos: Preparing for your next incident',
#  'Four short links: 1 August 2019',
#  'Learning from adversaries',
#  'Four short links: 31 July 2019',
#  'Four short links: 30 July 2019',
#  'Four short links: 29 July 2019',
#  'Four short links: 26 July 2019',
#  'Four short links: 25 July 2019',
#  'One simple graphic: Researchers love PyTorch and TensorFlow',
#  'Four short links: 24 July 2019',
#  'Four short links: 23 July 2019',
#  'Four short links: 22 July 2019',
#  'Four short links: 19 July 2019',
#  "O'Reilly Open Source and Frank Willison Awards",
#  'The war for the soul of open source',
#  'Open source force multipliers',
#  'O’Reilly Radar: Open source technology trends—What our users tell us',
#  'Ask not what Brands™ can do for you',
#  'Managing machines',
#  'Acquiring and sharing high-quality data',
#  'Four short links: 18 July 2019',
#  'The next age of open innovation',
#  'Why Amazon cares about open source',
#  'Better living through software',
#  "Highlights from the O'Reilly Open Source Software Conference in Portland 2019",
#  'The role of open source in mitigating natural disasters',
#  'Built to last: Building and growing open source communities']

# %% [markdown]
# ### 8. Calculate the percentage of "Four short links" entry titles.

# %%
# search for an element inside a list
four_short_links = [
    # return title
    title
    # iterate throght each element in title
    for title in titles
    # if the title contains 'For short links'
    if "Four short links" in title]

# %%
four_short_links
# Out:
# ['Four short links: 4 September 2019',
#  'Four short links: 3 September 2019',
#  'Four short links: 2 September 2019',
#  'Four short links: 30 August 2019',
#  'Four short links: 29 August 2019',
#  'Four short links: 28 August 2019',
#  'Four short links: 27 August 2019',
#  'Four short links: 26 August 2019',
#  'Four short links: 23 August 2019',
#  'Four short links: 22 August 2019',
#  'Four short links: 21 August 2019',
#  'Four short links: 20 August 2019',
#  'Four short links: 19 August 2019',
#  'Four short links: 15 August 2019',
#  'Four short links: 14 August 2019',
#  'Four short links: 13 August 2019',
#  'Four short links: 12 August 2019',
#  'Four short links: 9 August 2019',
#  'Four short links: 8 August 2019',
#  'Four short links: 7 August 2019',
#  'Four short links: 6 August 2019',
#  'Four short links: 5 August 2019',
#  'Four short links: 2 August 2019',
#  'Four short links: 1 August 2019',
#  'Four short links: 31 July 2019',
#  'Four short links: 30 July 2019',
#  'Four short links: 29 July 2019',
#  'Four short links: 26 July 2019',
#  'Four short links: 25 July 2019',
#  'Four short links: 24 July 2019',
#  'Four short links: 23 July 2019',
#  'Four short links: 22 July 2019',
#  'Four short links: 19 July 2019',
#  'Four short links: 18 July 2019']

# %%
# calculate the percentage ofr elements with 'Four short links'
perct = 100 * len(four_short_links) / len(titles)

# %%
print(f'"Four short links" represents {round(perct,2)}% of the list')
# Out:
# "Four short links" represents 56.67% of the list

# %% [markdown]
# ### 9. Create a Pandas data frame from the feed's entries.

# %%
import pandas as pd

# %%
# The dict format is a perfect match to be read with DataFrame() from pandas
df_entries = pd.DataFrame(feed_oreilly.entries)

# %%
df_entries.head(1)
# Out:
#   author author_detail authors  \
# 0    NaN           NaN     NaN
#
#                                              content  \
# 0  [{'type': 'text/html', 'language': None, 'base...
#
#                                  feedburner_origlink  guidislink  \
# 0  https://www.oreilly.com/ideas/new-live-online-...        True
#
#                                                   id  \
# 0  tag:www.oreilly.com,2019-09-04:/ideas/new-live...
#
#                                                 link  \
# 0  http://feedproxy.google.com/~r/oreilly/radar/a...
#
#                                                links  \
# 0  [{'href': 'http://feedproxy.google.com/~r/orei...
#
#                                              summary  \
# 0  <p><img src='https://d3ucjech6zwjp8.cloudfront...
#
#                               title  \
# 0  New live online training courses
#
#                                         title_detail               updated  \
# 0  {'type': 'text/plain', 'language': None, 'base...  2019-09-04T12:10:00Z
#
#                        updated_parsed
# 0  (2019, 9, 4, 12, 10, 0, 2, 247, 0)

# %% [markdown]
# * After creating the data frame, let's convert the 'updated' column into a datatime format

# %%
# write the string format accordingly to the 'updated' column
date_format = '%Y-%m-%d %H:%M:%S'

# %%
# create a new column 'datetime'
df_entries['datetime'] = pd.to_datetime(
    # call the pd.to_datetime passing the column and the format as an argument
    df_entries['updated'], format=date_format)

# %%
# check the number of posts by month using the dt.month argument
df_entries.datetime.dt.month.value_counts()
# Out:
# 7    41
# 6    19
# Name: datetime, dtype: int64

# %%
# check the number of posts by day of the week
df_entries.datetime.dt.weekday_name.value_counts()
# Out:
# Monday       16
# Wednesday    15
# Thursday     13
# Friday        9
# Tuesday       7
# Name: datetime, dtype: int64

# %% [markdown]
# * As we saw below, most of page's publications were posted on Mondays followed by Wednesdays

# %%
# Now let's check the time's publication
df_entries.datetime.dt.time.value_counts().head()
# Out:
# 20:00:00    11
# 15:50:00     8
# 11:00:00     7
# 08:00:00     3
# 10:45:00     3
# Name: datetime, dtype: int64

# %% [markdown]
# ### 10. Count the number of entries per author and sort them in descending order.

# %%
# grouping the entries by author and calling the size()
n_entries = df_entries.groupby(['author']).size()

# %%
# sort the entries at a descending order
n_entries = n_entries.sort_values(ascending=False)

# %%
n_entries.head()
# Out:
# author
# Nat Torkington                           26
# Ben Lorica                                5
# Ben Lorica, Harish Doddi, David Talby     2
# Jenn Webb                                 2
# VM Brasseur                               1
# dtype: int64

# %%
# we can write the code above in only one line
n_entries = df_entries.groupby(['author']).size().sort_values(ascending=False)

# %%
n_entries.head()
# Out:
# author
# Nat Torkington                           26
# Ben Lorica                                5
# Ben Lorica, Harish Doddi, David Talby     2
# Jenn Webb                                 2
# VM Brasseur                               1
# dtype: int64

# %% [markdown]
# ### 11. Add a new column to the data frame that contains the length (number of characters) of each entry title. Return a data frame that contains the title, author, and title length of each entry in descending order (longest title length at the top).

# %%
# Method 1: calling len() using the str method over the column 'title'
df_entries['len_title'] = df_entries['title'].str.len()

# %%
# Method 2: using apply() and lambda
df_entries['len_title'] = df_entries.title.apply(
    lambda x: len(x))

# %%
# Select the 'author', 'title', and 'len_title' columns
columns_df = ['author', 'title', 'len_title']

# %%
# subset the dataset with the columns_df list
new_df_entries = df_entries[columns_df]

# %%
new_df_entries.head()
# Out:
#            author                                              title  \
# 0  Nat Torkington                     Four short links: 19 July 2019
# 1      Adam Jacob                The war for the soul of open source
# 2     VM Brasseur                Ask not what Brands™ can do for you
# 3  Roger Magoulas  O’Reilly Radar: Open source technology trends—...
# 4             NaN     O'Reilly Open Source and Frank Willison Awards
#
#    len_title
# 0         30
# 1         35
# 2         35
# 3         68
# 4         46

# %%
# sort df by 'len_title'
new_df_entries = new_df_entries.sort_values('len_title',
                                           ascending=False)

# %%
new_df_entries.head()
# Out:
#                                    author  \
# 40                             Ben Lorica
# 16  Ben Lorica, Harish Doddi, David Talby
# 23                              Jenn Webb
# 11                             Mac Slocum
# 50                             Ben Lorica
#
#                                                 title  len_title
# 40  RISELab’s AutoPandas hints at automation tech ...         97
# 16  Managing machine learning in the enterprise: L...         81
# 23  Highlights from the O'Reilly Artificial Intell...         79
# 11  Highlights from the O'Reilly Open Source Softw...         77
# 50  Enabling end-to-end machine learning pipelines...         73

# %% [markdown]
# ### 12. Create a list of entry titles whose summary includes the phrase "machine learning."

# %%
# create a boolean mask filtering elements with 'machine learning'
mask = df_entries['summary'].str.contains('machine learning')

# %%
# subset the dataset
titles_ml = df_entries[mask]

# %%
# the new dataset contains 12 rows
titles_ml.shape
# Out:
# (12, 16)

# %%
# convert the titles which rows contains 'machine learning' to a list
titles_ml = list(titles_ml['title'])

# %%
titles_ml
# Out:
# ['Acquiring and sharing high-quality data',
#  "Highlights from the O'Reilly Open Source Software Conference in Portland 2019",
#  'Managing machine learning in the enterprise: Lessons from banking and health care',
#  "Highlights from the O'Reilly Artificial Intelligence Conference in Beijing 2019",
#  'The future of machine learning is tiny',
#  'Tools for machine learning development',
#  'New live online training courses',
#  'RISELab’s AutoPandas hints at automation tech that will change the nature of software development',
#  'AI and machine learning will require retraining your entire organization',
#  'Enabling end-to-end machine learning pipelines in real-world applications',
#  'What are model governance and model operations?',
#  'The quest for high-quality data']
