# %% [markdown]
# # Rock Paper Scissors
#
# Let's play the famous game against our computer.
#
# https://en.wikipedia.org/wiki/Rock%E2%80%93paper%E2%80%93scissors
#
# The use of functions is recommended
#
# ## Goals
# 1. Use of loop
# 2. Data capture by console
# 3. Use if-elif-else
# 4. Use of try-except
# 5. Definition of functions. Modular programming
# 6. Logical operators.
# 7. Print
# 8. Import modules

# %%
#Import the choice function of the random module
# https://stackoverflow.com/questions/306400/how-to-randomly-select-an-item-from-a-list
import random

# Assign to a list the 3 possible options: 'stone', 'paper' or 'scissors'.
plays = ["paper","stone","scissors"]
# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
ngame = 5
# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games
nwin = 3



# Define a function that randomly returns one of the 3 options.
# This will correspond to the play of the machine. Totally random.
def computer(plays):
    cplay = random.choice(plays)
    return cplay

# Define a function that asks your choice: 'stone', 'paper' or 'scissors'
# you should only allow one of the 3 options. This is defensive programming.
# If it is not stone, paper or scissors keep asking until it is.
def choice():
    pick = 1
    while pick <2 :
        pplay = str(input(" Pick stone, paper or scissors."))
        if pplay == "stone":
            return pplay
            pick = 3
        elif pplay == "paper" :
            return pplay
            pick = 3
        elif pplay == "scissors":
            return pplay
            pick=3
        else:
            print ("Try again")
            

    

# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player winsdef
def combat(cplay,pplay):
    
    if cplay == "stone":
        if pplay == "paper":
            return 2
        elif pplay == "scissors":
            return 1
        elif pplay == "stone":
            return 0
    elif cplay == "paper":
        if pplay == "scissors":
            return 2
        elif pplay == "stone":
            return 1
        elif pplay == "paper":
            return 0
    elif cplay == "scissors":
        if pplay == "stone":
            return 2
        elif pplay == "paper":
            return 1
        elif pplay == "scissors":
            return 0

# Define a function that shows the choice of each player and the state of the game
def results(cplay,pplay,combat): 
        if combat == 0:
            combat = "Tie"
        if combat == 1:
            combat = "Computer"
        if combat == 2:
            combat = "Player"
        s=[cplay,pplay,combat]
        return s   
    
# This function should be used every time accumulated points are updated
def points(cpoints,ppoints,combat):
        if combat == 1:
            cpoints += 1
            return (cpoints,ppoints)
        elif combat == 2:
            ppoints += 1
            return (cpoints, ppoints)
        else: 
            return (cpoints, ppoints)
        
# Create two variables that accumulate the wins of each participant
cpoints = 0
ppoints = 0
combatr = 0
# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.
result = []
i=0

while i < ngame:
    if cpoints >= nwin or ppoints >= nwin:
        break
    else:    
        cplay = computer(plays)
        pplay = choice()
        combatr = combat(cplay,pplay)
        result.append(results(cplay,pplay,combatr))
        cpoints , ppoints = points (cpoints,ppoints,combatr)
    i+= 1
    print(result)
# Print by console the winner of the game based on who has more accumulated wins
if cpoints > ppoints:
    print ("Computer wins!")
elif ppoints > cpoints:
    print ("Player wins!")

# %% [markdown]
# # Bonus: Stone, paper, scissors, lizard, spock
#
# Now the improvement begins.
#
# ![](images/rpsls.jpg)
#
#
# http://www.samkass.com/theories/RPSSL.html
#
# You are asked to impliment some improvements with respect to the simple previous game. In addition, the number of games (which must be ODD) will be requested per console until a valid number is entered.
#
# Improvements:
# * 5 options: stone, paper, scissors, lizard, spock
# * The number of games is requested per console
# Tip: Reuse code that you already use. If you have programmed intelligently, the bonus are simple modifications to the original game.

# %%
# Import the choice function of the random module

import random

# Define a function that asks for an odd number on the keyboard, until it is not valid
# will keep asking

def choicenumber():
    pick = 1
    ngame = int(input("Pick an odd number of games."))
    while pick <2 :
        if (ngame%2) != 0:
            pick = 3
            print ("Will play %d games"%ngame)
            return ngame
            break
            
        else:
            print ("Try again. Pick an odd number of games.")
            
# Assign a list of 5 possible options.
plays = ["paper","stone","scissors","spock","lizard"]

# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
# This time the previously defined function is used
ngame = choicenumber()

# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games
nwin = ngame - 2


# Define a function that randomly returns one of the 5 options.
# This will correspond to the play of the machine. Totally random.
def computer(plays):
    cplay = random.choice(plays)
    return cplay

# Define a function that asks your choice between 5
# you should only allow one of the 5 options. This is defensive programming.
# If it is not valid, keep asking until it is valid.
def choice():
    pick = 1
    while pick <2 :
        pplay = str(input(" Pick stone, paper, scissors, spock or lizard."))
        if pplay == "stone":
            return pplay
            pick = 3
        elif pplay == "paper" :
            return pplay
            pick = 3
        elif pplay == "scissors":
            return pplay
            pick=3
        elif pplay == "spock":
            return pplay
            pick =3
        elif pplay == "lizard":
            return pplay
            pick = 3
        else:
            print ("Try again")
            

    
# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins
# Now there are more options
 
def combat(cplay,pplay):
    
    if cplay == "stone":
        if pplay == "paper":
            return 2
        elif pplay == "scissors":
            return 1
        elif pplay == "stone":
            return 0
        elif pplay == "spock":
            return 1
        elif pplay == "lizard":
            return 2
    elif cplay == "paper":
        if pplay == "scissors":
            return 2
        elif pplay == "stone":
            return 1
        elif pplay == "paper":
            return 0
        elif pplay == "spock":
            return 1
        elif pplay == "lizard":
            return 2
    elif cplay == "scissors":
        if pplay == "stone":
            return 2
        elif pplay == "paper":
            return 1
        elif pplay == "scissors":
            return 0
        elif pplay == "spock":
            return 2
        elif pplay == "lizard":
            return 1
    elif cplay == "spock":
        if pplay == "stone":
            return 1
        elif pplay == "paper":
            return 2
        elif pplay == "scissors":
            return 1
        elif pplay == "spock":
            return 0
        elif pplay == "lizard":
            return 2
    elif cplay == "lizard":
        if pplay == "stone":
            return 2
        elif pplay == "paper":
            return 1
        elif pplay == "scissors":
            return 2
        elif pplay == "spock":
            return 1
        elif pplay == "lizard":
            return 0


# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated
def results(cplay,pplay,combat): 
        if combat == 0:
            combat = "Tie"
        if combat == 1:
            combat = "Computer"
        if combat == 2:
            combat = "Player"
        s=[cplay,pplay,combat]
        return s   
    
# This function should be used every time accumulated points are updated
def points(cpoints,ppoints,combat):
        if combat == 1:
            cpoints += 1
            return (cpoints,ppoints)
        elif combat == 2:
            ppoints += 1
            return (cpoints, ppoints)
        else: 
            return (cpoints, ppoints)
        
# Create two variables that accumulate the wins of each participant
cpoints = 0
ppoints = 0
combatr = 0

result = []
i=0

while i < ngame:
    if cpoints >= nwin or ppoints >= nwin:
        break
    else:    
        cplay = computer(plays)
        pplay = choice()
        combatr = combat(cplay,pplay)
        result.append(results(cplay,pplay,combatr))
        cpoints , ppoints = points (cpoints,ppoints,combatr)
    i+= 1
    print(result)
# Print by console the winner of the game based on who has more accumulated wins
if cpoints > ppoints:
    print ("Computer wins!")
elif ppoints > cpoints:
    print ("Player wins!")





    
    
# Print by console the winner of the game based on who has more accumulated wins
# Out:
# Pick an odd number of games.5
# Will play 5 games
#  Pick stone, paper, scissors, spock or lizard.spock
# [['spock', 'spock', 'Tie']]
#  Pick stone, paper, scissors, spock or lizard.lizard
# [['spock', 'spock', 'Tie'], ['paper', 'lizard', 'Player']]
#  Pick stone, paper, scissors, spock or lizard.scissors
# [['spock', 'spock', 'Tie'], ['paper', 'lizard', 'Player'], ['scissors', 'scissors', 'Tie']]
#  Pick stone, paper, scissors, spock or lizard.stone
# [['spock', 'spock', 'Tie'], ['paper', 'lizard', 'Player'], ['scissors', 'scissors', 'Tie'], ['scissors', 'stone', 'Player']]
#  Pick stone, paper, scissors, spock or lizard.paper
# [['spock', 'spock', 'Tie'], ['paper', 'lizard', 'Player'], ['scissors', 'scissors', 'Tie'], ['scissors', 'stone', 'Player'], ['scissors', 'paper', 'Computer']]
# Player wins!
